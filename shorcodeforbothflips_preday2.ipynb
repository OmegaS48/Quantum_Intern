# %%
from qiskit import QuantumCircuit

# %%
q=QuantumCircuit(11,2)

# %%
import numpy as np

# %%
a=1/np.sqrt(2)
b=1/np.sqrt(2)

# %%
q.initialize([a,b],0)

# %%
q.cx(0,3)
q.cx(0,6)
q.h(0)
q.h(3)
q.h(6)
